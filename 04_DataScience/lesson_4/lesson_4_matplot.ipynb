# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x = [ 1,2,3,4,5,6]

# %%
y = [0, 2, 4, 8, 10, 12]

# %%
plt.plot(x,y)

# %%
plt.show()

# %%
plt.scatter(x,y)

# %%
planets =
