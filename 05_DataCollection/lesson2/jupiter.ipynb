# %%
import pandas as pd

# %% [markdown]
# ### Вакансии с сайта hh.ru

# %%
df_file = 'hh_vacancies_Data_engineer.csv'

# %%
# !ls

# %%
df = pd.read_csv(df_file)

# %%
df.tail()
# Out:
#              site                     vacancy_url              vac_class  \
# 75  https://hh.ru  https://hh.ru/vacancy/49005874  vacancy_standard_plus
# 76  https://hh.ru  https://hh.ru/vacancy/48837237       vacancy_standard
# 77  https://hh.ru  https://hh.ru/vacancy/49589425  vacancy_standard_plus
# 78  https://hh.ru  https://hh.ru/vacancy/49186295  vacancy_standard_plus
# 79  https://hh.ru  https://hh.ru/vacancy/49497206  vacancy_standard_plus
#
#                             title              company          city  \
# 75                  Data Engineer                Точка  Екатеринбург
# 76                  Data Engineer              Playkot        Москва
# 77  Data engineer (middle/senior)             HR Prime        Москва
# 78                  Data engineer          ООО Ок Софт        Москва
# 79  Data Engineer / ETL Developer  Renaissance Capital        Москва
#
#     compensation_min  compensation_max currency
# 75               NaN          200000.0      RUB
# ...

# %%
pd.DataFrame({'nn': [1, 2, 3, 4], 'pp': [5,6,7,8]})
# Out:
#    nn  pp
# 0   1   5
# 1   2   6
# 2   3   7
# 3   4   8

# %% [markdown]
# ### Продукты с сайта Росконтроль.рф

# %%
filename = 'roscontrol_goods.csv'
df_goods_rc = pd.read_csv(filename)

# %%
df_goods_rc
# Out:
#                                                 title  security  nature  \
# 0          "Раменский деликатес" "Сервелат Коньячный"        74      80
# 1                   "БахрушинЪ", "Сервелат Коньячный"        64      35
# 2   Колбаса полукопченая "Мираторг", "Краковская",...        77      65
# 3                          "Велком", сервелат финский        58      12
# 4                      "Рублевский", сервелат финский        54      55
# ..                                                ...       ...     ...
# 65                  Колбаса полукопченая "Краковская"         0       0
# 66  Колбаса полукопченая "Клинский Мясокомбинат", ...         0       0
# 67  Колбаса варено-копченая "Снежана", Сервелат фи...         0       0
# 68    Колбаса полкопченая "Останкино", Венская салями         0       0
# 69  Колбаса варено-копченая "Микоян", Сервелат фин...         0       0
#
#     nutritional_value  quality  rate                   site  \
# ...
